# %%
descs = models.CurrentSnapshotDenormalizedDescription.query.filter_by(concept_id = 138875005).all()
descriptions=list(map(lambda desc: desc._to_dict(), descs))
filtered_descriptions=list(
    filter(
        lambda desc: desc['active'] == True and desc['module_id'] == 900000000000207008 and desc['type_id'] == 900000000000013009, 
        descriptions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8599176e1ed7> in <module>()
# ----> 1 descs = models.CurrentSnapshotDenormalizedDescription.query.filter_by(concept_id = 138875005).all()
#       2 descriptions=list(map(lambda desc: desc._to_dict(), descs))
#       3 filtered_descriptions=list(
#       4     filter(
#       5         lambda desc: desc['active'] == True and desc['module_id'] == 900000000000207008 and desc['type_id'] == 900000000000013009,
#
# NameError: name 'models' is not defined

# %%
[{"id": 3285253012, "effective_time": "2016-01-31", "type_id": 900000000000013009, "type_name": "Synonym (core metadata concept)", "term": "SNOMED Clinical Terms version: 20160131 [R] (January 2016 Release)", "module_name": "SNOMED CT core", "concept_id": 138875005, "case_significance_name": "Case sensitive", "case_significance_id": 900000000000017005, "language_reference_set_memberships": [{"refset": [{"concept_id": 900000000000509007, "preferred_term": "United States of America English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2016-01-31", "referenced_component_id": 3285253012, "active": true, "uuid": "86a1eaba-2c48-50bd-9ac0-fedbb3cc3830"}, {"refset": [{"concept_id": 900000000000508004, "preferred_term": "Great Britain English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2016-01-31", "referenced_component_id": 3285253012, "active": true, "uuid": "3fa6c5fd-1cae-5b93-ae7e-e62c5cedf370"}, {"refset": [{"concept_id": 999000671000001103, "preferred_term": "National Health Service dictionary of medicines and devices realm language reference set (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000001104, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000001108, "effective_time": "2016-04-01", "referenced_component_id": 3285253012, "active": true, "uuid": "feca1142-b616-5b60-849f-a0e8648bbf19"}, {"refset": [{"concept_id": 999001261000000100, "preferred_term": "National Health Service realm language reference set (clinical part) (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000000103, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000000109, "effective_time": "2016-04-01", "referenced_component_id": 3285253012, "active": true, "uuid": "119fff83-0b0a-578c-a97e-be74e3474633"}], "module_id": 900000000000207008, "active": true, "language_code": "en"}, {"id": 3285235018, "effective_time": "2016-01-31", "type_id": 900000000000013009, "type_name": "Synonym (core metadata concept)", "term": "\u00a9 2002-2016 International Health Terminology Standards Development Organisation (IHTSDO). All rights reserved. SNOMED CT\u00ae, was originally created by The College of American Pathologists. \"SNOMED\" and \"SNOMED CT\" are registered trademarks of the IHTSDO.", "module_name": "SNOMED CT core", "concept_id": 138875005, "case_significance_name": "Initial character case insensitive", "case_significance_id": 900000000000020002, "language_reference_set_memberships": [{"refset": [{"concept_id": 900000000000508004, "preferred_term": "Great Britain English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2016-01-31", "referenced_component_id": 3285235018, "active": true, "uuid": "a1dcb02e-5ede-5a97-9cc5-2f453b8c8b41"}, {"refset": [{"concept_id": 999000671000001103, "preferred_term": "National Health Service dictionary of medicines and devices realm language reference set (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000001104, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000001108, "effective_time": "2016-04-01", "referenced_component_id": 3285235018, "active": true, "uuid": "3d7250dc-51bc-5013-806b-59b20465ef26"}, {"refset": [{"concept_id": 999001261000000100, "preferred_term": "National Health Service realm language reference set (clinical part) (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000000103, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000000109, "effective_time": "2016-04-01", "referenced_component_id": 3285235018, "active": true, "uuid": "28827a90-91fe-500a-aa9c-41ac24b55cfc"}], "module_id": 900000000000207008, "active": true, "language_code": "en"}, {"id": 3009998017, "effective_time": "2014-07-31", "type_id": 900000000000013009, "type_name": "Synonym (core metadata concept)", "term": "SNOMED CT has been created by combining SNOMED RT and a computer-based nomenclature and classification known as Read Codes Version 3, which was created on behalf of the U.K. Department of Health.", "module_name": "SNOMED CT core", "concept_id": 138875005, "case_significance_name": "Case sensitive", "case_significance_id": 900000000000017005, "language_reference_set_memberships": [{"refset": [{"concept_id": 900000000000509007, "preferred_term": "United States of America English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2014-07-31", "referenced_component_id": 3009998017, "active": true, "uuid": "fa12c658-39ff-53d5-b9c1-37eca0239497"}, {"refset": [{"concept_id": 900000000000508004, "preferred_term": "Great Britain English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2014-07-31", "referenced_component_id": 3009998017, "active": true, "uuid": "2b26df27-2743-503e-be58-352e8cfbf9eb"}, {"refset": [{"concept_id": 999000671000001103, "preferred_term": "National Health Service dictionary of medicines and devices realm language reference set (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000001104, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000001108, "effective_time": "2015-01-07", "referenced_component_id": 3009998017, "active": true, "uuid": "13a5285f-424a-5902-8d69-a3cb328a61f7"}, {"refset": [{"concept_id": 999001261000000100, "preferred_term": "National Health Service realm language reference set (clinical part) (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000000103, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000000109, "effective_time": "2014-10-01", "referenced_component_id": 3009998017, "active": true, "uuid": "f7f3c60a-53dd-5055-a6b2-8112ca11c610"}], "module_id": 900000000000207008, "active": true, "language_code": "en"}, {"id": 220309016, "effective_time": "2003-07-31", "type_id": 900000000000013009, "type_name": "Synonym (core metadata concept)", "term": "SNOMED CT Concept", "module_name": "SNOMED CT core", "concept_id": 138875005, "case_significance_name": "Case sensitive", "case_significance_id": 900000000000017005, "language_reference_set_memberships": [{"refset": [{"concept_id": 900000000000509007, "preferred_term": "United States of America English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2002-01-31", "referenced_component_id": 220309016, "active": true, "uuid": "147cd051-3da6-56c9-ba82-f719e2ee3ed9"}, {"refset": [{"concept_id": 900000000000508004, "preferred_term": "Great Britain English language reference set (foundation metadata concept)", "effective_time": "2002-01-31", "module": 900000000000012004, "active": true, "definition_status": "Primitive"}], "module_id": 900000000000207008, "effective_time": "2002-01-31", "referenced_component_id": 220309016, "active": true, "uuid": "75302efc-dfad-5ca6-a7db-1650d8ddc69a"}, {"refset": [{"concept_id": 999000671000001103, "preferred_term": "National Health Service dictionary of medicines and devices realm language reference set (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000001104, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000001108, "effective_time": "2008-04-01", "referenced_component_id": 220309016, "active": true, "uuid": "099efad5-376f-5a06-b3bf-f18fcf00d828"}, {"refset": [{"concept_id": 999001261000000100, "preferred_term": "National Health Service realm language reference set (clinical part) (foundation metadata concept)", "effective_time": "2004-01-31", "module": 999000011000000103, "active": true, "definition_status": "Primitive"}], "module_id": 999000021000000109, "effective_time": "2011-10-03", "referenced_component_id": 220309016, "active": true, "uuid": "4e8242f5-ca50-5f61-a051-d39377322807"}], "module_id": 900000000000207008, "active": true, "language_code": "en"}]
